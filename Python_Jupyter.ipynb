# %%
1000*2533
# Out:
# 2533000

# %%
135*51
# Out:
# 6885

# %%
print("correct intend")

 print("incorrect intend")
# Out:
#   File "<ipython-input-6-55fd4a3082ab>", line 3
#     print("incorrect intend")
#     ^
# IndentationError: unexpected indent

# %%
print('원의 반지름', 5.0)
# Out:
# 원의 반지름 5.0

# %%
x=10
print('둘레', x*2*3.14)
# Out:
# 둘레 62.800000000000004

# %%
sum = 100
lst = [10,20,30]
total = sum(lst)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-bdae7446fdc7> in <module>
#       1 sum = 100
#       2 lst = [10,20,30]
# ----> 3 total = sum(lst)
#
# TypeError: 'int' object is not callable

# %%
name = '정상호'
age = 27
print('안녕! 나는', name,'이야. 나는 나이가', age, '살이야.')
# Out:
# 안녕! 나는 정상호 이야. 나는 나이가 27 살이야.

# %%
width = 20
height = 40
width = 30
area = width*height
print('사각형의 면적', area)
# Out:
# 사각형의 면적 1200

# %%
5%2
# Out:
# 1

# %%
x**2 = 2
# Out:
#   File "<ipython-input-9-2db1e1e63fa7>", line 1
#     x**2 = 2
#     ^
# SyntaxError: cannot assign to operator

# %%
root(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-af0aaef8a418> in <module>
# ----> 1 root(2)
#
# NameError: name 'root' is not defined

# %%
2**1/2
# Out:
# 1.0

# %%
math.sqrt(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-b1a01eea6359> in <module>
# ----> 1 math.sqrt(2)
#
# NameError: name 'math' is not defined

# %%
2**(1/2)
# Out:
# 1.4142135623730951

# %%
intnum=100
floatnum = 100.0
print(type(intnum))
print(type(floatnum))
# Out:
# <class 'int'>
# <class 'float'>

# %%
intNum=100
strDate="안녕"
print(intNum+strData)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-172163570b28> in <module>
#       1 intNum=100
#       2 strDate="안녕"
# ----> 3 print(intNum+strData)
#
# NameError: name 'strData' is not defined

# %%
hello = 여러분" 안녕하세요!!
print(hello)
# Out:
#   File "<ipython-input-6-6f0b37a30e00>", line 1
#     hello = 여러분" 안녕하세요!!
#                         ^
# SyntaxError: EOL while scanning string literal

# %%
hello = '"여러분" 안녕하세요'
print(hello)
# Out:
# "여러분" 안녕하세요

# %%
hello_1 = '''안녕하세요 반갑습니다 여기는 스마트팩토리 수업반 입니다 '''
print(hello_1)
# Out:
# 안녕하세요 반갑습니다 여기는 스마트팩토리 수업반 입니다

# %%
hello_2 = "안녕 \n 하세요"
print(hello_2)
# Out:
# 안녕
#  하세요

# %%
date = ''\U00000061'
print(data)
# Out:
#   File "<ipython-input-11-785de9d86f55>", line 1
#     date = ''\U00000061'
#                         ^
# SyntaxError: unexpected character after line continuation character

# %%
print(2==3)
# Out:
# False

# %%
print(2!=3)
# Out:
# True

# %%
print(2==3 & 4==2*2)
# Out:
# False

# %%
print(2==3 or 4==2*2)
# Out:
# True

# %%
#복소수 연산
number_1 = 2+3j
number_2 = 3+6j
print(number_1.imag)
print(number_1.real)
# Out:
# 3.0
# 2.0

# %%
print(number_1 + number_2)
print(number_1 - number_2)
print(number_1 * number_2)
print(number_1 / number_2)
# Out:
# (5+9j)
# (-1-3j)
# (-12+21j)
# (0.5333333333333333-0.06666666666666667j)

# %%
print(number_1.conjugate)
# Out:
# <built-in method conjugate of complex object at 0x06E3CE78>

# %%
#bool 테스트
bool(-1)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(1)
# Out:
# True

# %%
bool(2)
# Out:
# True

# %%
bool(none)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-88629cc5059d> in <module>
# ----> 1 bool(none)
#
# NameError: name 'none' is not defined

# %%
bool(None)
# Out:
# False

# %%
bool(!None)
# Out:
#   File "<ipython-input-32-47146352cb46>", line 1
#     bool(!None)
#          ^
# SyntaxError: invalid syntax

# %%
bool('')
# Out:
# False

# %%
str = ''
bool(!str)
# Out:
#   File "<ipython-input-34-9144abed2066>", line 2
#     bool(!str)
#          ^
# SyntaxError: invalid syntax

# %%
str = 'hello'
bool(str)
# Out:
# True

# %%
'''
이것은 지금 파이썬 데이터를 코딩하고 있는 중 입니다'''
# Out:
# '\n이것은 지금 파이썬 데이터를 코딩하고 있는 중 입니다'

# %%
input_data = input("당신이 사는 곳은?")
print(input_data)
# Out:
# 당신이 사는 곳은?seoul
# seoul

# %%
input_name = input(당신의 이름은?)
print(input_name, 님 반갑습니다')
# Out:
#   File "<ipython-input-44-843e2745d835>", line 2
#     print(input_name, 님 반갑습니다')
#
# ^
# SyntaxError: EOF while scanning triple-quoted string literal

# %%
num = 100;
print('num=', num)

num -= 100
print('num=', num)

num -= + 100
print('num=', num)
# Out:
# num= 100
# num= 0
# num= -100

# %%
철수 = 20
if 철수<20 :
    print("청소년 할인됩니다")
    print("돈내세요!!")

# %%
걸음걸이 = 1500
if 걸음걸이>=1000 :
    print("목표 달성")
print("수고하셨습니다")
# Out:
# 목표 달성
# 수고하셨습니다

# %%
step_data = input("걸음걸이를 입력하세요")
if int(step_data) >=1000 :
    print('목표 달성')
print("수고하셨습니다")
# Out:
# 걸음걸이를 입력하세요1200
# 목표 달성
# 수고하셨습니다

# %%
step_data = input("걸음걸이를 입력하세요")
if step_data >=1000 :
    print('목표 달성')
print("수고하셨습니다")
# Out:
# 걸음걸이를 입력하세요400
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-32a0e429c468> in <module>
#       1 step_data = input("걸음걸이를 입력하세요")
# ----> 2 if step_data >=1000 :
#       3     print('목표 달성')
#       4 print("수고하셨습니다")
#
# TypeError: '>=' not supported between instances of 'str' and 'int'

# %%
date_time = 9
if(date_time<12) :
    print("오전입니다")
else :
    print("오후입니다"
         )
# Out:
# 오전입니다

# %%
date_time = input("현재시각은?")
now_date = int(date_time)
if(date_time<12) :
    print("오전입니다")
else :
    print("오후입니다"
         )
# Out:
# 현재시각은?13
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-36aeefa9b68d> in <module>
#       1 date_time = input("현재시각은?")
#       2 now_date = int(date_time)
# ----> 3 if(date_time<12) :
#       4     print("오전입니다")
#       5 else :
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
date_time = input("현재시각은?")
now_date = int(date_time)
if(now_date<12) :
    print("오전입니다")
else :
    print("오후입니다"
         )
# Out:
# 현재시각은?15
# 오후입니다

# %%
man_power = input("전투력을 입력해주세요")
power = int(man_power)

if power <= 100:
    print("시비걸기")
    
elif 100 < power <= 200 :
    print("고민해보기")
elif power > 200:
    print("형님!!")
# Out:
# 전투력을 입력해주세요2000
# 형님!!

# %% [markdown]
# # while 문

# %%
while False :
    print("10분간 휴식")
# Out:
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# 10분간 휴식
# ...

# %% [markdown]
# # for 문

# %%
arr=range(6)
print(arr)
# Out:
# range(0, 6)

# %%
for i in range(6):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
arr = {"영희", "철수", "만수", "똘이"}
for i in arr:
    print(i)
# Out:
# 똘이
# 철수
# 영희
# 만수

# %%
for _ in range(10):
    print("안녕 월드")
# Out:
# 안녕 월드
# 안녕 월드
# 안녕 월드
# 안녕 월드
# 안녕 월드
# 안녕 월드
# 안녕 월드
# 안녕 월드
# 안녕 월드
# 안녕 월드

# %% [markdown]
# # range()
# ## range([start], [stop], [step])

# %%
arr = range(1, 10, 2)
print(len(arr))
for i in arr:
    print(i)
# Out:
# 5
# 1
# 3
# 5
# 7
# 9

# %% [markdown]
# ## 1부터 100까지의 합

# %%
sum = 0
for i in range(1,101):
    sum = sum + i
    print('1부터 100까지의 합은', sum)
# Out:
# 1부터 100까지의 합은 1
# 1부터 100까지의 합은 3
# 1부터 100까지의 합은 6
# 1부터 100까지의 합은 10
# 1부터 100까지의 합은 15
# 1부터 100까지의 합은 21
# 1부터 100까지의 합은 28
# 1부터 100까지의 합은 36
# 1부터 100까지의 합은 45
# 1부터 100까지의 합은 55
# 1부터 100까지의 합은 66
# 1부터 100까지의 합은 78
# 1부터 100까지의 합은 91
# 1부터 100까지의 합은 105
# 1부터 100까지의 합은 120
# 1부터 100까지의 합은 136
# 1부터 100까지의 합은 153
# 1부터 100까지의 합은 171
# 1부터 100까지의 합은 190
# 1부터 100까지의 합은 210
# 1부터 100까지의 합은 231
# 1부터 100까지의 합은 253
# 1부터 100까지의 합은 276
# 1부터 100까지의 합은 300
# 1부터 100까지의 합은 325
# 1부터 100까지의 합은 351
# 1부터 100까지의 합은 378
# 1부터 100까지의 합은 406
# 1부터 100까지의 합은 435
# 1부터 100까지의 합은 465
# 1부터 100까지의 합은 496
# 1부터 100까지의 합은 528
# 1부터 100까지의 합은 561
# 1부터 100까지의 합은 595
# 1부터 100까지의 합은 630
# 1부터 100까지의 합은 666
# 1부터 100까지의 합은 703
# 1부터 100까지의 합은 741
# 1부터 100까지의 합은 780
# 1부터 100까지의 합은 820
# 1부터 100까지의 합은 861
# 1부터 100까지의 합은 903
# 1부터 100까지의 합은 946
# 1부터 100까지의 합은 990
# 1부터 100까지의 합은 1035
# 1부터 100까지의 합은 1081
# 1부터 100까지의 합은 1128
# 1부터 100까지의 합은 1176
# 1부터 100까지의 합은 1225
# 1부터 100까지의 합은 1275
# ...

# %%
multi = 2
result = 1
for i in range(1, 10):
  result = multi*i
print(result), '곱하기', i, '는', result)
# Out:
#   File "<ipython-input-25-32f060e440c7>", line 5
#     print(result), '곱하기', i, '는', result)
#                                         ^
# SyntaxError: unmatched ')'

# %% [markdown]
# ## n factorial

# %%
n = int(input('input your nuber'))
fact=1
for i in range (1, n+1):
    fact = fact*i
print(fact)
# Out:
# input your nuber10
# 1
# 2
# 6
# 24
# 120
# 720
# 5040
# 40320
# 362880
# 3628800

# %%
n = int(input('합계를 구할 수를 입력하세요:'))
s = 0
i = 1
while i <= n:
    s = s+i
    i+= 1
    print('1부터 {}까지의 합은 {}'.format(n,s))
# Out:
# 합계를 구할 수를 입력하세요:10
# 1부터 10까지의 합은 1
# 1부터 10까지의 합은 3
# 1부터 10까지의 합은 6
# 1부터 10까지의 합은 10
# 1부터 10까지의 합은 15
# 1부터 10까지의 합은 21
# 1부터 10까지의 합은 28
# 1부터 10까지의 합은 36
# 1부터 10까지의 합은 45
# 1부터 10까지의 합은 55

# %%
n = int(input('합계를 구할 수를 입력하세요:'))
s = 0
i = 1
while i <= n:
    s = s+i
    i+= 1
print('1부터 {}까지의 합은 {}'.format(n,s))
# Out:
# 합계를 구할 수를 입력하세요:15
# 1부터 15까지의 합은 120

# %%
n = int(input('합계를 구할 수를 입력하세요:'))
s = 0
i = 1
while i <= n:
    s = s+i
    i+= 1
print('1부터 {}까지의 합은 {}'.format(s,n))
# Out:
# 합계를 구할 수를 입력하세요:15
# 1부터 120까지의 합은 15

# %%
n = int(input('합계를 구할 수를 입력하세요:'))
s = 0
i = 1
while i <= n:
    s = s+i
    i+= 1
print('1부터 {}까지의 합은 {},{}'.format(n,s,'안녕'))
# Out:
# 합계를 구할 수를 입력하세요:16
# 1부터 16까지의 합은 136,안녕

# %% [markdown]
# ## python literal sleected = None

# %%
n = -1
while n<=0:
    n = int(input('합계를 구할 양의 정수를 입력하세요 :'))

s = 0
for i in range(1, n+1):
    s = s+i
print('1부터 {}까지의 합은 {}'.format(n,s))
# Out:
# 합계를 구할 양의 정수를 입력하세요 :25
# 1부터 25까지의 합은 325

# %%
n = -1
while n<=0:
    n = int(input('합계를 구할 양의 정수를 입력하세요 :'))
    if(n<0):
        print('양수를 입력하세요')

        
s = 0
for i in range(1, n+1):
    s = s+i
print('1부터 {}까지의 합은 {}'.format(n,s))
# Out:
# 합계를 구할 양의 정수를 입력하세요 :-6
# 양수를 입력하세요
# 합계를 구할 양의 정수를 입력하세요 :10
# 1부터 10까지의 합은 55

# %%
n = -1
while n<=0:
    n = int(input('합계를 구할 양의 정수를 입력하세요 :'))
        
s = 0
for i in range(1, n+1):
    s = s+i
print('1부터 {}까지의 합은 {}'.format(n,s))
# Out:
# 합계를 구할 양의 정수를 입력하세요 :15
# 1부터 15까지의 합은 120

# %% [markdown]
# ## break, contiue

# %%
str = "Programming Language"
for i in str:
    print(i)
# Out:
# P
# r
# o
# g
# r
# a
# m
# m
# i
# n
# g
#
# L
# a
# n
# g
# u
# a
# g
# e

# %%
str = "Programming Language"
for i in str:
    if i in ['a', 'e', 'i', 'o', 'u'] :
        break
    print(i)
print("The end")
# Out:
# P
# r
# The end

# %%
bool('i',in ['i', 'a'])
# Out:
#   File "<ipython-input-9-2352a28c4aa9>", line 1
#     bool('i',in ['i', 'a'])
#              ^
# SyntaxError: invalid syntax

# %%
str = "Programming Language"
for i in str:
    if i in ['a', 'e', 'i', 'o', 'u'] :
        continue
    print(i)
print("The end")
# Out:
# P
# r
# g
# r
# m
# m
# n
# g
#
# L
# n
# g
# g
# The end

# %% [markdown]
# ## 제어문 if for while
